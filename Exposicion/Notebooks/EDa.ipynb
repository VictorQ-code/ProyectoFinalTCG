# %%
# 🔌 Montar Google Drive (opcional)
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# 📚 Librerías necesarias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 🎨 Estilo
sns.set(style="whitegrid")

# 🧩 Cargar CSV
file_path = "/content/drive/MyDrive/Proyecto API/Final Csv/all_cards_combined_with_tcg.csv"
df = pd.read_csv(file_path)

# Mostrar las primeras filas y la información general
df_info = df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18876 entries, 0 to 18875
# Data columns (total 41 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          18876 non-null  object
#  1   name                        18876 non-null  object
#  2   supertype                   18876 non-null  object
#  3   subtypes                    18876 non-null  object
#  4   rarity                      18876 non-null  object
#  5   set_id                      18876 non-null  object
#  6   set_name                    18876 non-null  object
#  7   number                      18876 non-null  object
#  8   artist                      18876 non-null  object
#  9   types                       18876 non-null  object
#  10  ancientTrait                18876 non-null  object
#  11  images_small                18876 non-null  object
#  12  images_large                18876 non-null  object
#  13  cardmarket_url              18876 non-null  object
#  14  cardmarket_updatedAt        18876 non-null  object
#  15  cm_averageSellPrice         18876 non-null  float64
#  16  cm_lowPrice                 18876 non-null  float64
#  17  cm_trendPrice               18876 non-null  float64
#  18  cm_germanProLow             18876 non-null  float64
#  19  cm_suggestedPrice           18876 non-null  float64
#  20  cm_reverseHoloSell          18876 non-null  float64
#  21  cm_reverseHoloLow           18876 non-null  float64
#  22  cm_reverseHoloTrend         18876 non-null  float64
#  23  cm_lowPriceExPlus           18876 non-null  float64
#  24  cm_avg1                     18876 non-null  float64
#  25  cm_avg7                     18876 non-null  float64
#  26  cm_avg30                    18876 non-null  float64
#  27  cm_reverseHoloAvg1          18876 non-null  float64
#  28  cm_reverseHoloAvg7          18876 non-null  float64
#  29  cm_reverseHoloAvg30         18876 non-null  float64
#  30  tcgplayer_url               18633 non-null  object
#  31  tcgplayer_updatedAt         18633 non-null  object
#  32  tcg_holofoil_low            6807 non-null   float64
#  33  tcg_holofoil_mid            6807 non-null   float64
#  34  tcg_holofoil_market         6789 non-null   float64
#  35  tcg_reverseHolofoil_low     11919 non-null  float64
#  36  tcg_reverseHolofoil_mid     11919 non-null  float64
#  37  tcg_reverseHolofoil_market  11911 non-null  float64
#  38  tcg_normal_low              11053 non-null  float64
#  39  tcg_normal_mid              11053 non-null  float64
#  40  tcg_normal_market           11028 non-null  float64
# dtypes: float64(24), object(17)
# memory usage: 5.9+ MB
